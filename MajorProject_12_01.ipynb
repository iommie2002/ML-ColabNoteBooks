# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip '/content/drive/MyDrive/Major Project/Dataset/UTKFace.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119160357804.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119181010188.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119200211340.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119200241996.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119200259595.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119200407188.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119204331863.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119204337838.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119205638160.jpg.chip.jpg
#   inflating: UTK face/utkface_aligned_cropped/UTKFace/52_0_3_20170119205639336.jpg.chip.jpg
# ...

# %%
# !pip install ktrain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 56.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 75.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 54.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ktrain: filename=ktrain-0.39.0-py3-none-any.whl size=25319737 sha256=2c444debb6d1ee3c063955ac59c3da93dbb2d416516349f8712e69803b495832
# ...

# %%
# %matplotlib inline
import os
import ktrain
from ktrain import vision as vis

# %%
import re
#this is the pattern to display the initial digit of file name as the age which will show only
#age as the single digit for the image that is present in the dataset .
pattern = r'([^/]+)_\d+_\d+_\d+.jpg.chip.jpg'

p=re.compile(pattern)
r=p.search('1_0_0_20161219190824794.jpg.chip.jpg')
print(r.group(1))
# Out:
# 1

# %%
DATADIR = '/content/drive/MyDrive/Major Project/Dataset/UTKFace.zip'

# %%
# %matplotlib inline
import os
import ktrain
from ktrain import vision as vis
import re

# Define the pattern to extract age from file names
pattern = r'([^/]+)_\d+_\d+_\d+.jpg.chip.jpg'

# Compile the regular expression pattern
p = re.compile(pattern)

# Test the pattern on a sample file name
r = p.search('1_0_0_20161219190824794.jpg.chip.jpg')
print(r.group(1))

# Specify the path to your dataset
DATADIR = '/content/drive/MyDrive/Major Project/Dataset/UTKFace.zip'

# Use images_from_fname to load the data
#(train_data, test_data, preproc) = vis.images_from_fname(DATADIR, pattern=pattern, is_regression=True, random_state=42)
# Out:
# 1

# %% [markdown]
# /content/drive/MyDrive/Major Project/Dataset/UTK Dataset.zip

# %%
from zipfile import ZipFile
# Specify the path to the zip file on Google Drive
zip_file_path = '/content/drive/MyDrive/Major Project/Dataset/UTKFace.zip'
extracted_folder_path = '/content/drive/MyDrive/Major Project/Dataset/UTKFace'

# Unzip the file
with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

# Use images_from_fname to load the data
(train_data, test_data, preproc) = vis.images_from_fname(extracted_folder_path, pattern=pattern, is_regression=True, random_state=42)

# Debugging: Print the number of samples in the training and testing sets
print(f"Number of samples in training set: {len(train_data.fnames)}")
print(f"Number of samples in testing set: {len(test_data.fnames)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2ffb7dd0baea> in <cell line: 11>()
#       9
#      10 # Use images_from_fname to load the data
# ---> 11 (train_data, test_data, preproc) = vis.images_from_fname(extracted_folder_path, pattern=pattern, is_regression=True, random_state=42)
#      12
#      13 # Debugging: Print the number of samples in the training and testing sets
#
# /usr/local/lib/python3.10/dist-packages/ktrain/vision/data.py in images_from_fname(train_folder, pattern, val_folder, is_regression, target_size, color_mode, data_aug, val_pct, random_state, verbose)
#     778             verbose=verbose,
#     779         )
# --> 780     return images_from_df(
#     781         train_df,
#     782         image_column,
#
# ...

# %%
DATADIR = '/content/drive/MyDrive/Major Project/Dataset/UTK Dataset.zip'
