# %%
import pandas as pd
df=pd.read_csv('/content/electronic-card-transactions-july-2023-csv-tables.csv')
df.head() # first five rows
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# 1  Electronic Card Transactions (ANZSIC06) - ECT
# 2  Electronic Card Transactions (ANZSIC06) - ECT
# 3  Electronic Card Transactions (ANZSIC06) - ECT
# 4  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
df.tail() # Last five rows
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 19740       ECTQ.S4AXP  2022.06        33.5        NaN      F  Percent
# 19741       ECTQ.S4AXP  2022.09        33.2        NaN      F  Percent
# 19742       ECTQ.S4AXP  2022.12        32.7        NaN      F  Percent
# 19743       ECTQ.S4AXP  2023.03        31.9        NaN      F  Percent
# 19744       ECTQ.S4AXP  2023.06        33.0        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 19740          0  Electronic Card Transactions (ANZSIC06) - ECT
# 19741          0  Electronic Card Transactions (ANZSIC06) - ECT
# 19742          0  Electronic Card Transactions (ANZSIC06) - ECT
# 19743          0  Electronic Card Transactions (ANZSIC06) - ECT
# 19744          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# 19740  Electronic card transactions by mean and propo...         Actual
# ...

# %%
df # entire dataset
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 19740       ECTQ.S4AXP  2022.06        33.5        NaN      F  Percent
# 19741       ECTQ.S4AXP  2022.09        33.2        NaN      F  Percent
# 19742       ECTQ.S4AXP  2022.12        32.7        NaN      F  Percent
# 19743       ECTQ.S4AXP  2023.03        31.9        NaN      F  Percent
# 19744       ECTQ.S4AXP  2023.06        33.0        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
import matplotlib.pyplot as plt
A=df['UNITS'].value_counts()
print(A)
# Out:
# Dollars    14384
# Percent     3244
# Number      2117
# Name: UNITS, dtype: int64

# %%
A.plot.bar(color=['green','yellow',])
# Out:
# <Axes: >

# %%
A.plot.barh(color=['green','yellow','blue'])
# Out:
# <Axes: >

# %%
b=pd.crosstab(df.UNITS,df.STATUS)
print(b)
b.plot.bar()
# Out:
# STATUS      C     F  P     R
# UNITS
# Dollars  1448  5029  8  7898
# Number    249  1829  8    30
# Percent   192  2058  0   994
# <Axes: xlabel='UNITS'>

# %%
b=pd.crosstab(df.UNITS,df.STATUS)
print(b)
b.plot.bar(stacked=True)
# Out:
# STATUS      C     F  P     R
# UNITS
# Dollars  1448  5029  8  7898
# Number    249  1829  8    30
# Percent   192  2058  0   994
# <Axes: xlabel='UNITS'>

# %%
b.T.plot.bar()
# Out:
# <Axes: xlabel='STATUS'>
